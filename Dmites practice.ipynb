# %%
# Write a Python program to check if a number is prime.

num = int(input("Enter a number"))

if num > 1:
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            print(num, "is not a prime number")
            break
    else:
        print(num, "is a prime number")

else:
    print(num, "is not a prime number")
# Out:
# 3 is a prime number

# %%
# factorial of a number
def factorial(n):
    if n == 0 or n==1:
        return 1
    return n*factorial(n-1)

print(factorial(5))
# Out:
# 120

# %%
# reverse a string

def reverrse_string(s):
    return s[::-1]

print (reverrse_string("hello"))
# Out:
# olleh

# %%
def first_non_repeating_char(s):
    freq = {}

    for ch in s:
        freq[ch] = freq.get(ch, 0) + 1

    for ch in s:
        if freq[ch] == 1:
            return ch
        
    return -1

s = "hello"
result = first_non_repeating_char(s)
print(result)
# Out:
# h

# %%
a = [ 1, 2]
b = [3, 4]
a + b
# Out:
# [1, 2, 3, 4]

# %%
['hai'] * 3
# Out:
# ['hai', 'hai', 'hai']

# %%
fruits = ['apple', 'orange']
fruits.append('grapes')
print(fruits)
# Out:
# ['apple', 'orange', 'grapes']

# %%
s = "anoop"
t = list(s)
t
# Out:
# ['a', 'n', 'o', 'o', 'p']

# %%
s = "how old are you"
t = s.split()
t
# Out:
# ['how', 'old', 'are', 'you']

# %%
fruits = ['apple', 'orange','grapes']

for fruit in fruits:
    print (fruit)
# Out:
# apple
# orange
# grapes
